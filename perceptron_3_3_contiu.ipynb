# %%
#This program is the implementation of example program of perceptron algorithm from Zurada's Introduction to Artificial Neural networks
#This uses continuous activation function
import math
import numpy as np
#/*----------------Function for perceptron algorithm --------------*/
def perceptron(c,X,d,w,iter,lam):
    for n in range(1,iter):# Number of iterations  = 7
        print ("Iteration ", n)
        print ("--------------")
        for i, x in enumerate(X):
            net = np.dot(X[i],w)
            out = (2/(1+math.exp(-lam*net)))-1
            r = c*(d[i] - out)*(1-(out*out))
            delta_w = 1/2*(r*x)
            w = delta_w+w
            print ("Step ", i, ":", w)
    return w
#/*---------------------Function for testing the perceptron-----------*/

def test_perceptron(final_out,X,w,lam):
    for i,x in enumerate(X):
        net = np.dot(X[i],w)
        out = (2/(1+math.exp(-lam*net)))-1
        final_out = final_out+[out]
    return final_out

#*---------------Training---------------------------------*/
X = np.array([[1,2],[-0.5,0],[2,1],[-1,1],])
new_input = np.array([[5,1],[-5,1],])#feed new inputs and see
print ("Inputs", X)
d = np.array([0,-1,1,-1])
print ("Teacher values", d)
w= ([1,1])
print ("initial values of weights", w)
c = 1
iterations = 6
lam=1
print ("Training")
print ("----------")
final_weight = perceptron(c,X,d,w,iterations,lam)
print ("Final sets of weights: ", final_weight)
#*-----------------Testing-------------------------------*/
final_out = []
print ("Testing")
print ("--------")
final_output = test_perceptron(final_out,new_input,final_weight,lam)
print ("Final output: ", final_output)
#print ("Original Teacher values", d)
# Out:
# Inputs [[ 1.   2. ]
#  [-0.5  0. ]
#  [ 2.   1. ]
#  [-1.   1. ]]
# Teacher values [ 0 -1  1 -1]
# initial values of weights [1, 1]
# Training
# ----------
# Iteration  1
# --------------
# Step  0 : [0.91821685 0.8364337 ]
# Step  1 : [1.10196179 0.8364337 ]
# Step  2 : [1.11786233 0.84438397]
# Step  3 : [1.54193697 0.42030933]
# Iteration  2
# --------------
# Step  0 : [1.41335154 0.16313846]
# Step  1 : [1.55950004 0.16313846]
# Step  2 : [1.56959806 0.16818747]
# Step  3 : [1.69491085 0.04287469]
# Iteration  3
# --------------
# Step  0 : [ 1.51926769 -0.30841163]
# Step  1 : [ 1.65768369 -0.30841163]
# Step  2 : [ 1.67460392 -0.29995151]
# Step  3 : [ 1.72679715 -0.35214475]
# Iteration  4
# --------------
# Step  0 : [ 1.54355383 -0.71863139]
# Step  1 : [ 1.68021991 -0.71863139]
# Step  2 : [ 1.71324114 -0.70212077]
# Step  3 : [ 1.7379367  -0.72681633]
# Iteration  5
# --------------
# Step  0 : [ 1.66874325 -0.86520323]
# Step  1 : [ 1.79654089 -0.86520323]
# Step  2 : [ 1.82480259 -0.85107238]
# Step  3 : [ 1.84032927 -0.86659905]
# Final sets of weights:  [ 1.84032927 -0.86659905]
# Testing
# --------
# Final output:  [0.9995201994310017, -0.9999151936898805]
