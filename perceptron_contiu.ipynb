# %%
#This program is the implementation of example program of perceptron algorithm from Zurada's Introduction to Artificial Neural networks
#This uses continuous activation function
import math
import numpy as np
#/*----------------Function for perceptron algorithm --------------*/
def perceptron(c,X,d,w,iter,lam):
    for n in range(1,iter):# Number of iterations 
        print ("Iteration ", n)
        print ("--------------")
        for i, x in enumerate(X):
            net = np.dot(X[i],w)
            out = (2/(1+math.exp(-lam*net)))-1
            r = c*(d[i] - out)
            delta_w = r*x
            w = delta_w+w
            print ("Step ", i, ":", w)
    return w
#/*---------------------Function for testing the perceptron-----------*/

def test_perceptron(final_out,X,w):
    for i,x in enumerate(X):
        net = np.dot(X[i],w)
        out = (2/(1+math.exp(-lam*net)))-1
        final_out = final_out+[out]
    return final_out

#*---------------Training---------------------------------*/
X = np.array([[1,-1,0,-1],[0,2.5,-0.5,-1],[-1,2,0.5,-1],])
print ("Inputs", X)
d = np.array([-1,-1,0])
print ("Teacher values", d)
w= ([1,1,0,0.5])
print ("initial values of weights", w)
c = 0.1
lam = 0.9#lambda value
iterations = 7
print ("Training")
print ("----------")
final_weight = perceptron(c,X,d,w,iterations,lam)
print ("Final sets of weights: ", final_weight)
#*-----------------Testing-------------------------------*/
final_out = []
print ("Testing")
print ("--------")
final_output = test_perceptron(final_out,X,final_weight)
print ("Final output: ", final_output)
print ("Original Teacher values", d)
# Out:
# Inputs [[ 1.  -1.   0.  -1. ]
#  [ 0.   2.5 -0.5 -1. ]
#  [-1.   2.   0.5 -1. ]]
# Teacher values [-1 -1  0]
# initial values of weights [1, 1, 0, 0.5]
# Training
# ----------
# Iteration  1
# --------------
# Step  0 : [0.92212785 1.07787215 0.         0.57787215]
# Step  1 : [0.92212785 0.64263678 0.08704707 0.7519663 ]
# Step  2 : [0.90671334 0.6734658  0.09475433 0.73655179]
# Iteration  2
# --------------
# Step  0 : [0.82898255 0.75119659 0.09475433 0.81428258]
# Step  1 : [0.82898255 0.39421625 0.1661504  0.95707472]
# Step  2 : [0.79000398 0.47217339 0.18563968 0.91809615]
# Iteration  3
# --------------
# Step  0 : [0.71637758 0.54579979 0.18563968 0.99172254]
# Step  1 : [0.71637758 0.26447019 0.2419056  1.10425438]
# Step  2 : [0.66808197 0.3610614  0.26605341 1.05595878]
# Iteration  4
# --------------
# Step  0 : [0.60056361 0.42857977 0.26605341 1.12347714]
# Step  1 : [0.60056361 0.1993504  0.31189928 1.21516889]
# Step  2 : [0.54921248 0.30205266 0.33757484 1.16381776]
# Iteration  5
# --------------
# Step  0 : [0.48827148 0.36299366 0.33757484 1.22475876]
# Step  1 : [0.48827148 0.16681998 0.37680958 1.30322823]
# Step  2 : [0.43664346 0.27007601 0.40262359 1.25160022]
# Iteration  6
# --------------
# Step  0 : [0.38192727 0.3247922  0.40262359 1.30631641]
# Step  1 : [0.38192727 0.15059257 0.43746351 1.37599626]
# Step  2 : [0.33134479 0.25175753 0.46275475 1.32541378]
# Final sets of weights:  [0.33134479 0.25175753 0.46275475 1.32541378]
# Testing
# --------
# Final output:  [-0.5084387353627986, -0.39467769957061194, -0.39257432014102134]
# Original Teacher values [-1 -1  0]
